# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x=np.array([12,45,78,23,15,20,73,99])
y=np.arange(0,24,3)
z=np.linspace(0,20,8,dtype=int)

# %%
fig=plt.figure(figsize=(10,10),facecolor="pink")
ax=plt.axes(projection="3d")
ax.set_facecolor("Gray")
ax.scatter3D(x,y,z, color="black", marker="d",depthshade=False)
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
ax.set_zlabel("z axis")
#ax.view_init(45,0)
ax.set_title("Scatter Plot")
ax.plot3D(x,y,z, color="cyan")
fig.show()

# %%
df=pd.read_csv("batter.csv")
df
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
fig=plt.figure(figsize=(12,10),facecolor="#268fb5")
ax=plt.axes(projection="3d")
ax.set_facecolor("#eba4ab")
ax.scatter3D(df["runs"],df["avg"],df["strike_rate"], marker="d",depthshade=False, color="#c71022",)
ax.set_xlabel("Runs", color="#28075e")
ax.set_ylabel("Average", color="#28075e")
ax.set_zlabel("Strike Rate", color="#28075e")
#ax.view_init(45,0)
ax.set_title("IPL Analysis", color="#0c2e5e")
fig.show()
