# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,5,3,8,9]
y=[1,5,3,8,9]
plt.scatter(x,y)
plt.text(1,1,"Point1")
plt.show()
# Out:
# Text(1, 1, 'Point1')

# %%
df=pd.read_csv("batter.csv")
df=df.head(25)
df
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.scatter(df["avg"],df["strike_rate"])
plt.text(df["avg"].values[0],df["strike_rate"].values[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspaces/Codes/Visualization/Exp8.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell://codespaces%2Bbug-free-chainsaw-6qxrxrv5qpp3rvqj/workspaces/Codes/Visualization/Exp8.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> plt.scatter(df["avg"],df["strike_rate"])
# ----> <a href='vscode-notebook-cell://codespaces%2Bbug-free-chainsaw-6qxrxrv5qpp3rvqj/workspaces/Codes/Visualization/Exp8.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> plt.text(df["avg"].values[0],df["strike_rate"].values[0])
#       <a href='vscode-notebook-cell://codespaces%2Bbug-free-chainsaw-6qxrxrv5qpp3rvqj/workspaces/Codes/Visualization/Exp8.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.show()
#
# TypeError: text() missing 1 required positional argument: 's'
