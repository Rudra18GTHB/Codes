# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns;

# %%
plt.boxplot([10,20,30,40,50,60,70,120],vert=True,notch=True,showmeans=True,patch_artist=True,boxprops={'color':"red"},capprops={'color':'Orange'},whiskerprops={'color':'Yellow'},sym="g+")
plt.show()

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.boxplot([df["sepal_length"],df["sepal_width"],df["petal_length"],df["petal_width"]],vert=False,showmeans=True,notch=True,patch_artist=True,sym="r*",boxprops={'color':"pink"},capprops={'color':'Orange'},whiskerprops={'color':'Orange'},labels=["sepal_length","sepal_width","petal_length","petal_width"])
plt.title("Species")
plt.show()
