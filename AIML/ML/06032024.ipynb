# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../DataSet/COVID-19_India_Data.csv")
df
# Out:
#            date  new_cases  cum_cases  new_death  cum_death  new_recovered  \
# 0    2020-01-30          1          1          0          0              0
# 1    2020-01-31          0          1          0          0              0
# 2    2020-02-01          0          1          0          0              0
# 3    2020-02-02          1          2          0          0              0
# 4    2020-02-03          1          3          0          0              0
# ..          ...        ...        ...        ...        ...            ...
# 636  2021-10-27      16351   34231030        734     455828          17077
# 637  2021-10-28      14307   34245337        805     456633          13189
# 638  2021-10-29      14215   34259552        551     457184          13549
# 639  2021-10-30      12940   34272492        445     457629          14672
# 640  2021-10-31      12907   34285399        251     457880          13152
#
#      cum_recovered  cum_active_cases
# ...

# %%
plt.plot(df["cum_cases"], label = "Cum Cases")
plt.plot(df["cum_death"], label = "Cum Death")
plt.plot(df["cum_recovered"], label = "Cum Recovered")
plt.plot(df["cum_active_cases"], label = "Cum Active Cases")
plt.plot(df["new_cases"], label ="New Cases")
plt.plot(df["new_death"], label = "New Deaths")
plt.plot(df["new_recovered"], label ="New Recovered")
plt.legend()
plt.show()

# %%
df = pd.read_csv("../DataSet/heart_failure_clinical_records_dataset.csv")
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
columns = ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes','ejection_fraction', 'high_blood_pressure', 'platelets','serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time','DEATH_EVENT']

# %%
X=df.drop(columns=["DEATH_EVENT"],axis=1)
Y=df["DEATH_EVENT"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, random_state=2)

# %%
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array([ 1.34160176e-01, -6.31126636e-02,  2.14513175e-01,  3.98565797e-01,
#         2.97609316e-01,  7.99232094e-01,  3.76557539e-01,  3.22341598e-01,
#        -2.45911710e-04,  3.09804491e-01,  4.86860660e-01,  1.13530550e-01,
#         8.69079113e-01,  2.01201766e-02,  2.83200583e-01, -7.74296273e-06,
#         1.03813037e-02,  3.49247518e-01,  3.80863034e-01,  1.10864211e-01,
#         7.70989935e-01,  3.73411040e-01,  7.57780167e-01,  2.62791260e-01,
#         6.82479970e-01,  5.89043068e-01,  8.03626173e-02,  7.79926177e-02,
#         5.92964974e-02,  2.96554088e-01,  1.26927236e-01,  6.60567676e-01,
#         1.60487937e-01,  2.29773978e-01,  4.31988724e-01, -2.12895762e-01,
#         3.37889484e-01,  5.62720511e-01,  6.73312267e-01, -2.59267093e-02,
#         6.25569956e-01,  1.72738620e-01,  3.59117894e-01,  1.71965958e-01,
#         2.18301937e-01,  6.59091019e-01,  1.92309229e-01, -4.16673153e-02,
# ...
